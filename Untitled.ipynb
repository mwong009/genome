# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/test_data.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df) == pd.DataFrame
a = 1

# %%
try:
    type(a) == pd.DataFrame
    print('df is dataframe')
except TypeError as te:
    print(te)

# %%
if not type(a) is pd.DataFrame:
    raise TypeError("only pandas.DataFrame object is allowed")

# %%
columns = df.columns
frame = {columns[i]: df.iloc[:,i] for i in range(len(columns))}

# %%
columns
# Out:
# Index(['gid', 'weekend', 'hour_8_10', 'hour_11_13', 'hour_14_16', 'hour_17_19',
#        'hour_20_22', 'hour_23_1', 'hour_2_4', 'hour_5_7', 'num_coord',
#        'trip_dist', 'trip_time', 'trip_aspeed', 'act_edu', 'act_health',
#        'act_leisure', 'act_meal', 'act_errand', 'act_shop', 'act_home',
#        'act_work', 'act_meeting', 'mode'],
#       dtype='object')

# %%
df[['hour_20_22','hour_8_10']].shape[1]
# Out:
# 2

# %%
df[['mode']].max(axis=0)
# Out:
# mode    7
# dtype: int64

# %%
from genome.optimizers import *

# %%
DEFAULT_OPTIMIZERS = {
    'SGD': SGD,
    'MomentumSGD': MomentumSGD,
    'Adagrad': Adagrad,
    'RMSProp': RMSProp,
    'Adadelta': Adadelta,
    'Adam': Adam,
}

name = 'SG1D'

try:
    DEFAULT_OPTIMIZERS[name]
except KeyError:
    print('optimizer \'' + name + '\' not found')
finally:
    print('hello')
    
if name in DEFAULT_OPTIMIZERS:
    print('true')
else:
    raise KeyError('not found')
# Out:
# optimizer 'SG1D' not found
# hello
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-cbf8a2809415> in <module>
#      20     print('true')
#      21 else:
# ---> 22     raise KeyError('not found')
#
# KeyError: 'not found'
